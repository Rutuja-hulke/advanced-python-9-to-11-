# %% [markdown]
# ## API

# %% [markdown]
# https://rapidapi.com/auth/sign-up

# %% [markdown]
# ## Retrieve the most popular movies from IMDB websites

# %% [markdown]
# https://rapidapi.com/davethebeast/api/imdb232/playground/apiendpoint_ed81b485-3368-4e1d-8e9a-6b632af4771d

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %pip install python-dotenv requests
# Out:
# Requirement already satisfied: python-dotenv in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: requests in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\desktop\advanced python 9 to 11\repository\venv\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv  import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os 
api_key = os.getenv("API_KEY")

# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

querystring = {"limit":"20","topMeterTitlesType":"ALL"}

headers = {
	"x-rapidapi-key": api_key, 
	"x-rapidapi-host": "imdb232.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

#print(response.json())
data =response.json()

# %%
data
# Out:
# {'data': {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#       'id': 'tt5950044',
#       'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm530548482',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#        'height': 2048,
#        'width': 1638},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 10}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31036941',
#       'titleText': {'text': 'Jurassic World: Rebirth',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Jurassic World: Rebirth',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3920935426',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDE1N2EzMjAtMDY1My00YWE5LWEyYjYtYmE3YjZjNzQwNDhmXkEyXkFqcGc@._V1_.jpg',
#        'height': 1800,
#        'width': 1257},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt33043892',
#       'titleText': {'text': 'Dexter: Resurrection', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Dexter: Resurrection',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1286584834',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMzgxNzUwZTctMzliNi00MDUwLWE4YzctNjgwMDE2OWQwNzMxXkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 52}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt26676904',
#       'titleText': {'text': 'Ballard', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ballard', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 9,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1465826050',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmZlN2MzNGQtMTg4Yy00N2RmLThkZWQtMjVmMmE3MmY4ODIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'UP', 'difference': 139}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt16311594',
#       'titleText': {'text': 'F1: The Movie', 'isOriginalTitle': False},
#       'originalTitleText': {'text': 'F1', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 27,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3614620162',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZTYwYjJhNzYtY2ZiZS00ZmYxLWJkZjctYjRlNGIxYjI3ZTU0XkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2025},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31193180',
#       'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 18,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm448960002',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31806049',
#       'titleText': {'text': 'Brick', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Brick', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 10,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1508423682',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMGRjZTI5NmEtNWQzNi00ZDUxLWFmZmQtOGFiZmNkZGY1MDc5XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1007}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt1751634',
#       'titleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 8,
#        'day': 5,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1163704322',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjk0M2ZhZTQtZjQ0NC00ODA2LWFkN2ItMTA0ZTc0MjJjODg0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10919420',
#       'titleText': {'text': 'Squid Game', 'isOriginalTitle': False},
#       'originalTitleText': {'text': 'Ojing-eo geim', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 9,
#        'day': 17,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1256044546',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYTU3ZDVhNmMtMDVlNC00MDc0LTgwNDMtYWE5MTI2ZGI4YWIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1500,
#        'width': 1013},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14452776',
#       'titleText': {'text': 'The Bear', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Bear', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 23,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2946467586',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWZhNDZiMzAtZmZlYS00MWFmLWE2MWEtNDAxZTZiN2U4Y2U2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13357520',
#       'titleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4139417602',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWFmNjg0ZGMtZmI5OC00YTAwLWFiMmMtOWRkNzQ0OTE1YWEwXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30406366',
#       'titleText': {'text': 'Too Much', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Too Much', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 10,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm593214210',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOThkZGJjM2ItZDI5ZS00Yjc4LTk1YzQtZGM3ZDNhMTUyOTMyXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'UP', 'difference': 346}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10676052',
#       'titleText': {'text': 'The Fantastic Four: First Steps',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Fantastic Four: First Steps',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 25,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1312471298',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOGM5MzA3MDAtYmEwMi00ZDNiLTg4MDgtMTZjOTc0ZGMyNTIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1609,
#        'width': 1086},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'UP', 'difference': 12}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10548174',
#       'titleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#       'originalTitleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2284624130',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjgwYTI0YjctMWYzNS00MmI1LWI5YTctNmE1YjBkNDFlNWMxXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14205554',
#       'titleText': {'text': 'KPop Demon Hunters', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'KPop Demon Hunters',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3070985218',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNTBiYWJlMjQtOTIyMy00NTY4LWFhOWItOWZhNzc3NGMyMjc2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1500,
#        'width': 1013},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 9,
#        'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31216548',
#       'titleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 19,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3892937730',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYjllZDZiNzUtZTE5MS00MTNjLWJlMDAtZGY4YjM5YTVkM2UxXkEyXkFqcGc@._V1_.jpg',
#        'height': 8002,
#        'width': 5401},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7181546',
#       'titleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 6,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1352172290',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNzdhZmY2OTQtYWI4OC00ZThkLTlhZjAtNzE2YzRjM2Q5YjJlXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2025},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 10,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14961624',
#       'titleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Old Guard 2',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2590934530',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmFhNWY1MjEtZTkyZS00ZWIzLTk4ZWItMDM0MzliNmE1ZGZhXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 11,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 6}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13623126',
#       'titleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 24,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2993915650',
#        'url': 'https://m.media-amazon.com/images/M/MV5BN2EzMGZhOTktYjVhZi00NmIwLWIxZDEtNWUxZTQyNjhkYWQ4XkEyXkFqcGc@._V1_.jpg',
#        'height': 1608,
#        'width': 1086},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt20969586',
#       'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4030707970',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWE2NmNmYTItZGY0ZC00MmY2LTk1NDAtMGUyMGEzMjcxNWM0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2818,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 12,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}}]}}}

# %%
type(data)
# Out:
# dict

# %%
empdata ={
    "name":["Rutuja","thaman"]
}

# %%
empdata.get("name")
# Out:
# ['Rutuja', 'thaman']

# %%
empdata.get("id","no data")
# Out:
# 'no data'

# %%
empdata.get("id",[])
# Out:
# []

# %%
data
# Out:
# {'data': {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#       'id': 'tt5950044',
#       'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm530548482',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#        'height': 2048,
#        'width': 1638},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 10}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31036941',
#       'titleText': {'text': 'Jurassic World: Rebirth',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Jurassic World: Rebirth',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3920935426',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDE1N2EzMjAtMDY1My00YWE5LWEyYjYtYmE3YjZjNzQwNDhmXkEyXkFqcGc@._V1_.jpg',
#        'height': 1800,
#        'width': 1257},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt33043892',
#       'titleText': {'text': 'Dexter: Resurrection', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Dexter: Resurrection',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1286584834',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMzgxNzUwZTctMzliNi00MDUwLWE4YzctNjgwMDE2OWQwNzMxXkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 52}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt26676904',
#       'titleText': {'text': 'Ballard', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ballard', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 9,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1465826050',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmZlN2MzNGQtMTg4Yy00N2RmLThkZWQtMjVmMmE3MmY4ODIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'UP', 'difference': 139}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt16311594',
#       'titleText': {'text': 'F1: The Movie', 'isOriginalTitle': False},
#       'originalTitleText': {'text': 'F1', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 27,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3614620162',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZTYwYjJhNzYtY2ZiZS00ZmYxLWJkZjctYjRlNGIxYjI3ZTU0XkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2025},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31193180',
#       'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 18,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm448960002',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31806049',
#       'titleText': {'text': 'Brick', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Brick', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 10,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1508423682',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMGRjZTI5NmEtNWQzNi00ZDUxLWFmZmQtOGFiZmNkZGY1MDc5XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1007}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt1751634',
#       'titleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 8,
#        'day': 5,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1163704322',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjk0M2ZhZTQtZjQ0NC00ODA2LWFkN2ItMTA0ZTc0MjJjODg0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10919420',
#       'titleText': {'text': 'Squid Game', 'isOriginalTitle': False},
#       'originalTitleText': {'text': 'Ojing-eo geim', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 9,
#        'day': 17,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1256044546',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYTU3ZDVhNmMtMDVlNC00MDc0LTgwNDMtYWE5MTI2ZGI4YWIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1500,
#        'width': 1013},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14452776',
#       'titleText': {'text': 'The Bear', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Bear', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 23,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2946467586',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWZhNDZiMzAtZmZlYS00MWFmLWE2MWEtNDAxZTZiN2U4Y2U2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13357520',
#       'titleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4139417602',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWFmNjg0ZGMtZmI5OC00YTAwLWFiMmMtOWRkNzQ0OTE1YWEwXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30406366',
#       'titleText': {'text': 'Too Much', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Too Much', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 10,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm593214210',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOThkZGJjM2ItZDI5ZS00Yjc4LTk1YzQtZGM3ZDNhMTUyOTMyXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'UP', 'difference': 346}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10676052',
#       'titleText': {'text': 'The Fantastic Four: First Steps',
#        'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Fantastic Four: First Steps',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 25,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1312471298',
#        'url': 'https://m.media-amazon.com/images/M/MV5BOGM5MzA3MDAtYmEwMi00ZDNiLTg4MDgtMTZjOTc0ZGMyNTIwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1609,
#        'width': 1086},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'UP', 'difference': 12}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt10548174',
#       'titleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#       'originalTitleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2284624130',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjgwYTI0YjctMWYzNS00MmI1LWI5YTctNmE1YjBkNDFlNWMxXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14205554',
#       'titleText': {'text': 'KPop Demon Hunters', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'KPop Demon Hunters',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3070985218',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNTBiYWJlMjQtOTIyMy00NTY4LWFhOWItOWZhNzc3NGMyMjc2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1500,
#        'width': 1013},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 9,
#        'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31216548',
#       'titleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 19,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3892937730',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYjllZDZiNzUtZTE5MS00MTNjLWJlMDAtZGY4YjM5YTVkM2UxXkEyXkFqcGc@._V1_.jpg',
#        'height': 8002,
#        'width': 5401},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7181546',
#       'titleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 6,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1352172290',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNzdhZmY2OTQtYWI4OC00ZThkLTlhZjAtNzE2YzRjM2Q5YjJlXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2025},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 10,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt14961624',
#       'titleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Old Guard 2',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2590934530',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmFhNWY1MjEtZTkyZS00ZWIzLTk4ZWItMDM0MzliNmE1ZGZhXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 11,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 6}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13623126',
#       'titleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 6,
#        'day': 24,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2993915650',
#        'url': 'https://m.media-amazon.com/images/M/MV5BN2EzMGZhOTktYjVhZi00NmIwLWIxZDEtNWUxZTQyNjhkYWQ4XkEyXkFqcGc@._V1_.jpg',
#        'height': 1608,
#        'width': 1086},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt20969586',
#       'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 5,
#        'day': 2,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4030707970',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYWE2NmNmYTItZGY0ZC00MmY2LTk1NDAtMGUyMGEzMjcxNWM0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2818,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 12,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}}]}}}

# %%
data.get("data",{})
# Out:
# {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#      'id': 'tt5950044',
#      'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 11,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm530548482',
#       'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#       'height': 2048,
#       'width': 1638},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 1,
#       'rankChange': {'changeDirection': 'UP', 'difference': 10}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31036941',
#      'titleText': {'text': 'Jurassic World: Rebirth', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Jurassic World: Rebirth',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 2,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3920935426',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMDE1N2EzMjAtMDY1My00YWE5LWEyYjYtYmE3YjZjNzQwNDhmXkEyXkFqcGc@._V1_.jpg',
#       'height': 1800,
#       'width': 1257},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 2,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt33043892',
#      'titleText': {'text': 'Dexter: Resurrection', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Dexter: Resurrection',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 11,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1286584834',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMzgxNzUwZTctMzliNi00MDUwLWE4YzctNjgwMDE2OWQwNzMxXkEyXkFqcGc@._V1_.jpg',
#       'height': 4000,
#       'width': 2700},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 1,
#       'rankChange': {'changeDirection': 'UP', 'difference': 52}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt26676904',
#      'titleText': {'text': 'Ballard', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Ballard', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 9,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1465826050',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNmZlN2MzNGQtMTg4Yy00N2RmLThkZWQtMjVmMmE3MmY4ODIwXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 2,
#       'rankChange': {'changeDirection': 'UP', 'difference': 139}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt16311594',
#      'titleText': {'text': 'F1: The Movie', 'isOriginalTitle': False},
#      'originalTitleText': {'text': 'F1', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 27,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3614620162',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZTYwYjJhNzYtY2ZiZS00ZmYxLWJkZjctYjRlNGIxYjI3ZTU0XkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2025},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 3,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31193180',
#      'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 4,
#       'day': 18,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm448960002',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#       'height': 4096,
#       'width': 2764},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 4,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31806049',
#      'titleText': {'text': 'Brick', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Brick', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 10,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1508423682',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMGRjZTI5NmEtNWQzNi00ZDUxLWFmZmQtOGFiZmNkZGY1MDc5XkEyXkFqcGc@._V1_.jpg',
#       'height': 2222,
#       'width': 1500},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 5,
#       'rankChange': {'changeDirection': 'UP', 'difference': 1007}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt1751634',
#      'titleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 8,
#       'day': 5,
#       'year': 2022,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1163704322',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNjk0M2ZhZTQtZjQ0NC00ODA2LWFkN2ItMTA0ZTc0MjJjODg0XkEyXkFqcGc@._V1_.jpg',
#       'height': 2222,
#       'width': 1500},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 3,
#       'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt10919420',
#      'titleText': {'text': 'Squid Game', 'isOriginalTitle': False},
#      'originalTitleText': {'text': 'Ojing-eo geim', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 9,
#       'day': 17,
#       'year': 2021,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1256044546',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYTU3ZDVhNmMtMDVlNC00MDc0LTgwNDMtYWE5MTI2ZGI4YWIwXkEyXkFqcGc@._V1_.jpg',
#       'height': 1500,
#       'width': 1013},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 4,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt14452776',
#      'titleText': {'text': 'The Bear', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Bear', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 23,
#       'year': 2022,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2946467586',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYWZhNDZiMzAtZmZlYS00MWFmLWE2MWEtNDAxZTZiN2U4Y2U2XkEyXkFqcGc@._V1_.jpg',
#       'height': 1350,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 5,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt13357520',
#      'titleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 2,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm4139417602',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYWFmNjg0ZGMtZmI5OC00YTAwLWFiMmMtOWRkNzQ0OTE1YWEwXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 6,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt30406366',
#      'titleText': {'text': 'Too Much', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Too Much', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 10,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvMiniSeries',
#       'text': 'TV Mini Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm593214210',
#       'url': 'https://m.media-amazon.com/images/M/MV5BOThkZGJjM2ItZDI5ZS00Yjc4LTk1YzQtZGM3ZDNhMTUyOTMyXkEyXkFqcGc@._V1_.jpg',
#       'height': 2222,
#       'width': 1500},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 6,
#       'rankChange': {'changeDirection': 'UP', 'difference': 346}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt10676052',
#      'titleText': {'text': 'The Fantastic Four: First Steps',
#       'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Fantastic Four: First Steps',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 25,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1312471298',
#       'url': 'https://m.media-amazon.com/images/M/MV5BOGM5MzA3MDAtYmEwMi00ZDNiLTg4MDgtMTZjOTc0ZGMyNTIwXkEyXkFqcGc@._V1_.jpg',
#       'height': 1609,
#       'width': 1086},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 7,
#       'rankChange': {'changeDirection': 'UP', 'difference': 12}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt10548174',
#      'titleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#      'originalTitleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 20,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2284624130',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNjgwYTI0YjctMWYzNS00MmI1LWI5YTctNmE1YjBkNDFlNWMxXkEyXkFqcGc@._V1_.jpg',
#       'height': 1350,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 8,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt14205554',
#      'titleText': {'text': 'KPop Demon Hunters', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'KPop Demon Hunters',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 20,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3070985218',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNTBiYWJlMjQtOTIyMy00NTY4LWFhOWItOWZhNzc3NGMyMjc2XkEyXkFqcGc@._V1_.jpg',
#       'height': 1500,
#       'width': 1013},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 9,
#       'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31216548',
#      'titleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 19,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3892937730',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYjllZDZiNzUtZTE5MS00MTNjLWJlMDAtZGY4YjM5YTVkM2UxXkEyXkFqcGc@._V1_.jpg',
#       'height': 8002,
#       'width': 5401},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 7,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt7181546',
#      'titleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 6,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1352172290',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNzdhZmY2OTQtYWI4OC00ZThkLTlhZjAtNzE2YzRjM2Q5YjJlXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2025},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 10,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt14961624',
#      'titleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 2,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2590934530',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZmFhNWY1MjEtZTkyZS00ZWIzLTk4ZWItMDM0MzliNmE1ZGZhXkEyXkFqcGc@._V1_.jpg',
#       'height': 1350,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 11,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 6}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt13623126',
#      'titleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 6,
#       'day': 24,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvMiniSeries',
#       'text': 'TV Mini Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2993915650',
#       'url': 'https://m.media-amazon.com/images/M/MV5BN2EzMGZhOTktYjVhZi00NmIwLWIxZDEtNWUxZTQyNjhkYWQ4XkEyXkFqcGc@._V1_.jpg',
#       'height': 1608,
#       'width': 1086},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 8,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt20969586',
#      'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 5,
#       'day': 2,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm4030707970',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYWE2NmNmYTItZGY0ZC00MmY2LTk1NDAtMGUyMGEzMjcxNWM0XkEyXkFqcGc@._V1_.jpg',
#       'height': 2818,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 12,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}}]}}

# %%
data.get("data").get("topMeterTitles")
# Out:
# {'edges': [{'node': {'__typename': 'Title',
#     'id': 'tt5950044',
#     'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 11,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm530548482',
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#      'height': 2048,
#      'width': 1638},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 1,
#      'rankChange': {'changeDirection': 'UP', 'difference': 10}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31036941',
#     'titleText': {'text': 'Jurassic World: Rebirth', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Jurassic World: Rebirth',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 2,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3920935426',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDE1N2EzMjAtMDY1My00YWE5LWEyYjYtYmE3YjZjNzQwNDhmXkEyXkFqcGc@._V1_.jpg',
#      'height': 1800,
#      'width': 1257},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 2,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt33043892',
#     'titleText': {'text': 'Dexter: Resurrection', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Dexter: Resurrection',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 11,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1286584834',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzgxNzUwZTctMzliNi00MDUwLWE4YzctNjgwMDE2OWQwNzMxXkEyXkFqcGc@._V1_.jpg',
#      'height': 4000,
#      'width': 2700},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 1,
#      'rankChange': {'changeDirection': 'UP', 'difference': 52}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt26676904',
#     'titleText': {'text': 'Ballard', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Ballard', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 9,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1465826050',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmZlN2MzNGQtMTg4Yy00N2RmLThkZWQtMjVmMmE3MmY4ODIwXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 2,
#      'rankChange': {'changeDirection': 'UP', 'difference': 139}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt16311594',
#     'titleText': {'text': 'F1: The Movie', 'isOriginalTitle': False},
#     'originalTitleText': {'text': 'F1', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 27,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3614620162',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZTYwYjJhNzYtY2ZiZS00ZmYxLWJkZjctYjRlNGIxYjI3ZTU0XkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2025},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 3,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31193180',
#     'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 4,
#      'day': 18,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm448960002',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#      'height': 4096,
#      'width': 2764},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 4,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31806049',
#     'titleText': {'text': 'Brick', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Brick', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 10,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1508423682',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMGRjZTI5NmEtNWQzNi00ZDUxLWFmZmQtOGFiZmNkZGY1MDc5XkEyXkFqcGc@._V1_.jpg',
#      'height': 2222,
#      'width': 1500},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 5,
#      'rankChange': {'changeDirection': 'UP', 'difference': 1007}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt1751634',
#     'titleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 8,
#      'day': 5,
#      'year': 2022,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1163704322',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjk0M2ZhZTQtZjQ0NC00ODA2LWFkN2ItMTA0ZTc0MjJjODg0XkEyXkFqcGc@._V1_.jpg',
#      'height': 2222,
#      'width': 1500},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 3,
#      'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt10919420',
#     'titleText': {'text': 'Squid Game', 'isOriginalTitle': False},
#     'originalTitleText': {'text': 'Ojing-eo geim', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 9,
#      'day': 17,
#      'year': 2021,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1256044546',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYTU3ZDVhNmMtMDVlNC00MDc0LTgwNDMtYWE5MTI2ZGI4YWIwXkEyXkFqcGc@._V1_.jpg',
#      'height': 1500,
#      'width': 1013},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 4,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt14452776',
#     'titleText': {'text': 'The Bear', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Bear', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 23,
#      'year': 2022,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2946467586',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWZhNDZiMzAtZmZlYS00MWFmLWE2MWEtNDAxZTZiN2U4Y2U2XkEyXkFqcGc@._V1_.jpg',
#      'height': 1350,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 5,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt13357520',
#     'titleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 2,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm4139417602',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWFmNjg0ZGMtZmI5OC00YTAwLWFiMmMtOWRkNzQ0OTE1YWEwXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 6,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt30406366',
#     'titleText': {'text': 'Too Much', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Too Much', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 10,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvMiniSeries',
#      'text': 'TV Mini Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm593214210',
#      'url': 'https://m.media-amazon.com/images/M/MV5BOThkZGJjM2ItZDI5ZS00Yjc4LTk1YzQtZGM3ZDNhMTUyOTMyXkEyXkFqcGc@._V1_.jpg',
#      'height': 2222,
#      'width': 1500},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 6,
#      'rankChange': {'changeDirection': 'UP', 'difference': 346}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt10676052',
#     'titleText': {'text': 'The Fantastic Four: First Steps',
#      'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Fantastic Four: First Steps',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 25,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1312471298',
#      'url': 'https://m.media-amazon.com/images/M/MV5BOGM5MzA3MDAtYmEwMi00ZDNiLTg4MDgtMTZjOTc0ZGMyNTIwXkEyXkFqcGc@._V1_.jpg',
#      'height': 1609,
#      'width': 1086},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 7,
#      'rankChange': {'changeDirection': 'UP', 'difference': 12}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt10548174',
#     'titleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#     'originalTitleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 20,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2284624130',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjgwYTI0YjctMWYzNS00MmI1LWI5YTctNmE1YjBkNDFlNWMxXkEyXkFqcGc@._V1_.jpg',
#      'height': 1350,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 8,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt14205554',
#     'titleText': {'text': 'KPop Demon Hunters', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'KPop Demon Hunters',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 20,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3070985218',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNTBiYWJlMjQtOTIyMy00NTY4LWFhOWItOWZhNzc3NGMyMjc2XkEyXkFqcGc@._V1_.jpg',
#      'height': 1500,
#      'width': 1013},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 9,
#      'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31216548',
#     'titleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 19,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3892937730',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYjllZDZiNzUtZTE5MS00MTNjLWJlMDAtZGY4YjM5YTVkM2UxXkEyXkFqcGc@._V1_.jpg',
#      'height': 8002,
#      'width': 5401},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 7,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt7181546',
#     'titleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 6,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1352172290',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzdhZmY2OTQtYWI4OC00ZThkLTlhZjAtNzE2YzRjM2Q5YjJlXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2025},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 10,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt14961624',
#     'titleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 2,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2590934530',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZmFhNWY1MjEtZTkyZS00ZWIzLTk4ZWItMDM0MzliNmE1ZGZhXkEyXkFqcGc@._V1_.jpg',
#      'height': 1350,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 11,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 6}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt13623126',
#     'titleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 6,
#      'day': 24,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvMiniSeries',
#      'text': 'TV Mini Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2993915650',
#      'url': 'https://m.media-amazon.com/images/M/MV5BN2EzMGZhOTktYjVhZi00NmIwLWIxZDEtNWUxZTQyNjhkYWQ4XkEyXkFqcGc@._V1_.jpg',
#      'height': 1608,
#      'width': 1086},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 8,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt20969586',
#     'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 5,
#      'day': 2,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm4030707970',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYWE2NmNmYTItZGY0ZC00MmY2LTk1NDAtMGUyMGEzMjcxNWM0XkEyXkFqcGc@._V1_.jpg',
#      'height': 2818,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 12,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}}]}

# %%
data.get("data").get("topMeterTitles").get("edges")
# Out:
# [{'node': {'__typename': 'Title',
#    'id': 'tt5950044',
#    'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 11,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm530548482',
#     'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#     'height': 2048,
#     'width': 1638},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 1,
#     'rankChange': {'changeDirection': 'UP', 'difference': 10}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31036941',
#    'titleText': {'text': 'Jurassic World: Rebirth', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Jurassic World: Rebirth',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 2,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3920935426',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMDE1N2EzMjAtMDY1My00YWE5LWEyYjYtYmE3YjZjNzQwNDhmXkEyXkFqcGc@._V1_.jpg',
#     'height': 1800,
#     'width': 1257},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 2,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt33043892',
#    'titleText': {'text': 'Dexter: Resurrection', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Dexter: Resurrection',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 11,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1286584834',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMzgxNzUwZTctMzliNi00MDUwLWE4YzctNjgwMDE2OWQwNzMxXkEyXkFqcGc@._V1_.jpg',
#     'height': 4000,
#     'width': 2700},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 1,
#     'rankChange': {'changeDirection': 'UP', 'difference': 52}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt26676904',
#    'titleText': {'text': 'Ballard', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Ballard', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 9,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1465826050',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNmZlN2MzNGQtMTg4Yy00N2RmLThkZWQtMjVmMmE3MmY4ODIwXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 2,
#     'rankChange': {'changeDirection': 'UP', 'difference': 139}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt16311594',
#    'titleText': {'text': 'F1: The Movie', 'isOriginalTitle': False},
#    'originalTitleText': {'text': 'F1', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 27,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3614620162',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZTYwYjJhNzYtY2ZiZS00ZmYxLWJkZjctYjRlNGIxYjI3ZTU0XkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2025},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 3,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31193180',
#    'titleText': {'text': 'Sinners', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Sinners', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 4,
#     'day': 18,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm448960002',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNjIwZWY4ZDEtMmIxZS00NDA4LTg4ZGMtMzUwZTYyNzgxMzk5XkEyXkFqcGc@._V1_.jpg',
#     'height': 4096,
#     'width': 2764},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 4,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31806049',
#    'titleText': {'text': 'Brick', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Brick', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 10,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1508423682',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMGRjZTI5NmEtNWQzNi00ZDUxLWFmZmQtOGFiZmNkZGY1MDc5XkEyXkFqcGc@._V1_.jpg',
#     'height': 2222,
#     'width': 1500},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 5,
#     'rankChange': {'changeDirection': 'UP', 'difference': 1007}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt1751634',
#    'titleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Sandman', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 8,
#     'day': 5,
#     'year': 2022,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1163704322',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNjk0M2ZhZTQtZjQ0NC00ODA2LWFkN2ItMTA0ZTc0MjJjODg0XkEyXkFqcGc@._V1_.jpg',
#     'height': 2222,
#     'width': 1500},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 3,
#     'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt10919420',
#    'titleText': {'text': 'Squid Game', 'isOriginalTitle': False},
#    'originalTitleText': {'text': 'Ojing-eo geim', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 9,
#     'day': 17,
#     'year': 2021,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1256044546',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYTU3ZDVhNmMtMDVlNC00MDc0LTgwNDMtYWE5MTI2ZGI4YWIwXkEyXkFqcGc@._V1_.jpg',
#     'height': 1500,
#     'width': 1013},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 4,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt14452776',
#    'titleText': {'text': 'The Bear', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Bear', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 23,
#     'year': 2022,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2946467586',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYWZhNDZiMzAtZmZlYS00MWFmLWE2MWEtNDAxZTZiN2U4Y2U2XkEyXkFqcGc@._V1_.jpg',
#     'height': 1350,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 5,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt13357520',
#    'titleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Heads of State', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 2,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm4139417602',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYWFmNjg0ZGMtZmI5OC00YTAwLWFiMmMtOWRkNzQ0OTE1YWEwXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 6,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt30406366',
#    'titleText': {'text': 'Too Much', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Too Much', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 10,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvMiniSeries',
#     'text': 'TV Mini Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm593214210',
#     'url': 'https://m.media-amazon.com/images/M/MV5BOThkZGJjM2ItZDI5ZS00Yjc4LTk1YzQtZGM3ZDNhMTUyOTMyXkEyXkFqcGc@._V1_.jpg',
#     'height': 2222,
#     'width': 1500},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 6,
#     'rankChange': {'changeDirection': 'UP', 'difference': 346}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt10676052',
#    'titleText': {'text': 'The Fantastic Four: First Steps',
#     'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Fantastic Four: First Steps',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 25,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1312471298',
#     'url': 'https://m.media-amazon.com/images/M/MV5BOGM5MzA3MDAtYmEwMi00ZDNiLTg4MDgtMTZjOTc0ZGMyNTIwXkEyXkFqcGc@._V1_.jpg',
#     'height': 1609,
#     'width': 1086},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 7,
#     'rankChange': {'changeDirection': 'UP', 'difference': 12}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt10548174',
#    'titleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#    'originalTitleText': {'text': '28 Years Later', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 20,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2284624130',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNjgwYTI0YjctMWYzNS00MmI1LWI5YTctNmE1YjBkNDFlNWMxXkEyXkFqcGc@._V1_.jpg',
#     'height': 1350,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 8,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt14205554',
#    'titleText': {'text': 'KPop Demon Hunters', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'KPop Demon Hunters',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 20,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3070985218',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNTBiYWJlMjQtOTIyMy00NTY4LWFhOWItOWZhNzc3NGMyMjc2XkEyXkFqcGc@._V1_.jpg',
#     'height': 1500,
#     'width': 1013},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 9,
#     'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31216548',
#    'titleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Waterfront', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 19,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3892937730',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYjllZDZiNzUtZTE5MS00MTNjLWJlMDAtZGY4YjM5YTVkM2UxXkEyXkFqcGc@._V1_.jpg',
#     'height': 8002,
#     'width': 5401},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 7,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt7181546',
#    'titleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Ballerina', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 6,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1352172290',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNzdhZmY2OTQtYWI4OC00ZThkLTlhZjAtNzE2YzRjM2Q5YjJlXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2025},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 10,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt14961624',
#    'titleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Old Guard 2', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 2,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2590934530',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZmFhNWY1MjEtZTkyZS00ZWIzLTk4ZWItMDM0MzliNmE1ZGZhXkEyXkFqcGc@._V1_.jpg',
#     'height': 1350,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 11,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 6}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt13623126',
#    'titleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Ironheart', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 6,
#     'day': 24,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvMiniSeries',
#     'text': 'TV Mini Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2993915650',
#     'url': 'https://m.media-amazon.com/images/M/MV5BN2EzMGZhOTktYjVhZi00NmIwLWIxZDEtNWUxZTQyNjhkYWQ4XkEyXkFqcGc@._V1_.jpg',
#     'height': 1608,
#     'width': 1086},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 8,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 4}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt20969586',
#    'titleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Thunderbolts*', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 5,
#     'day': 2,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm4030707970',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYWE2NmNmYTItZGY0ZC00MmY2LTk1NDAtMGUyMGEzMjcxNWM0XkEyXkFqcGc@._V1_.jpg',
#     'height': 2818,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 12,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}}]

# %%
data.get("data").get("topMeterTitles").get("edges")[0]
# Out:
# {'node': {'__typename': 'Title',
#   'id': 'tt5950044',
#   'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#   'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#   'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#   'releaseDate': {'__typename': 'ReleaseDate',
#    'month': 7,
#    'day': 11,
#    'year': 2025,
#    'country': {'id': 'US'},
#    'restriction': None,
#    'attributes': [],
#    'displayableProperty': {'qualifiersInMarkdownList': None}},
#   'titleType': {'__typename': 'TitleType',
#    'id': 'movie',
#    'text': 'Movie',
#    'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#    'canHaveEpisodes': False,
#    'isEpisode': False,
#    'isSeries': False,
#    'displayableProperty': {'value': {'plainText': ''}}},
#   'primaryImage': {'__typename': 'Image',
#    'id': 'rm530548482',
#    'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#    'height': 2048,
#    'width': 1638},
#   'meterRanking': {'__typename': 'TitleMeterRanking',
#    'currentRank': 1,
#    'rankChange': {'changeDirection': 'UP', 'difference': 10}}}}

# %%
movie1 = data.get("data").get("topMeterTitles").get("edges")[0]
movie1.get("node",{})
# Out:
# {'__typename': 'Title',
#  'id': 'tt5950044',
#  'titleText': {'text': 'Superman', 'isOriginalTitle': True},
#  'originalTitleText': {'text': 'Superman', 'isOriginalTitle': True},
#  'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#  'releaseDate': {'__typename': 'ReleaseDate',
#   'month': 7,
#   'day': 11,
#   'year': 2025,
#   'country': {'id': 'US'},
#   'restriction': None,
#   'attributes': [],
#   'displayableProperty': {'qualifiersInMarkdownList': None}},
#  'titleType': {'__typename': 'TitleType',
#   'id': 'movie',
#   'text': 'Movie',
#   'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#   'canHaveEpisodes': False,
#   'isEpisode': False,
#   'isSeries': False,
#   'displayableProperty': {'value': {'plainText': ''}}},
#  'primaryImage': {'__typename': 'Image',
#   'id': 'rm530548482',
#   'url': 'https://m.media-amazon.com/images/M/MV5BOGMwZGJiM2EtMzEwZC00YTYzLWIxNzYtMmJmZWNlZjgxZTMwXkEyXkFqcGc@._V1_.jpg',
#   'height': 2048,
#   'width': 1638},
#  'meterRanking': {'__typename': 'TitleMeterRanking',
#   'currentRank': 1,
#   'rankChange': {'changeDirection': 'UP', 'difference': 10}}}

# %%
movie1 = data.get("data").get("topMeterTitles").get("edges")[0]
nd = movie1.get("node",{})
nd
title = nd.get("titleText",{}).get("text",{})
release_year = nd.get("releaseYear",{}).get("year",{})
rank = nd.get("meterRanking",{}).get("currentRanking",{})
print(title,release_year,rank)
# Out:
# Superman 2025 {}

# %%
nodes = data.get("data").get("topMeterTitles").get("edges")
for node in nodes:
    nd = node.get("node",{})
    title = nd.get("titleText",{}).get("text",{})
    release_year = nd.get("releaseYear",{}).get("year",{})
    rank = nd.get("meterRanking",{}).get("currentRank",{})
    print(title,release_year,rank)
# Out:
# Superman 2025 1
# Jurassic World: Rebirth 2025 2
# Dexter: Resurrection 2025 1
# Ballard 2025 2
# F1: The Movie 2025 3
# Sinners 2025 4
# Brick 2025 5
# The Sandman 2022 3
# Squid Game 2021 4
# The Bear 2022 5
# Heads of State 2025 6
# Too Much 2025 6
# The Fantastic Four: First Steps 2025 7
# 28 Years Later 2025 8
# KPop Demon Hunters 2025 9
# The Waterfront 2025 7
# Ballerina 2025 10
# The Old Guard 2 2025 11
# Ironheart 2025 8
# Thunderbolts* 2025 12

# %%
l1 = [2,3,4,5]
for i in l1:
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
nodes = data.get("data").get("topMeterTitles").get("edges")
top_movie_data = []
for node in nodes: 
    nd = node.get("node",{})
    title = nd.get("titleText",{}).get("text",{})
    release_year = nd.get("releaseYear",{}).get("year",{})
    rank = nd.get("meterRanking",{}).get("currentRank",{})
    #print(title,release_year,rank)
    top_movie_data.append([title,release_year,rank])
print(top_movie_data)
# Out:
# [['Superman', 2025, 1], ['Jurassic World: Rebirth', 2025, 2], ['Dexter: Resurrection', 2025, 1], ['Ballard', 2025, 2], ['F1: The Movie', 2025, 3], ['Sinners', 2025, 4], ['Brick', 2025, 5], ['The Sandman', 2022, 3], ['Squid Game', 2021, 4], ['The Bear', 2022, 5], ['Heads of State', 2025, 6], ['Too Much', 2025, 6], ['The Fantastic Four: First Steps', 2025, 7], ['28 Years Later', 2025, 8], ['KPop Demon Hunters', 2025, 9], ['The Waterfront', 2025, 7], ['Ballerina', 2025, 10], ['The Old Guard 2', 2025, 11], ['Ironheart', 2025, 8], ['Thunderbolts*', 2025, 12]]

# %%
l1 = [2,3,4,5]
l2 = []
l3 = []
for i in l1:
    l2.append(i)
    l2.append(i**2)
    l3.append([i,i**2])
print(l2)
print(l3)
# Out:
# [2, 4, 3, 9, 4, 16, 5, 25]
# [[2, 4], [3, 9], [4, 16], [5, 25]]

# %%
# to save the extracted/collected data to a csv file
import csv
with open("Top_movies.csv","w",encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Movie Titles","Release Year","Rank"])
    writer.writerows(top_movie_data)

# %%
import requests,csv

# %%
class api_extracter:
    def __init__(self,api_key):
        self.api_key = api_key

    def get_data(self):
        url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

        querystring = {"limit":"20","topMeterTitlesType":"ALL"}

        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "imdb232.p.rapidapi.com"
        }

        response = requests.get(url, headers=headers, params=querystring)

        #print(response.json())
        data = response.json()

        nodes = data.get("data").get("topMeterTitles").get("edges")
        top_movie_data = []
        for node in nodes:
            nd = node.get("node",{})
            title = nd.get("titleText",{}).get("text",{})
            release_year = nd.get("releaseYear",{}).get("year",{})
            rank = nd.get("meterRanking",{}).get("currentRank",{})
            #print(title,release_year,rank)
            top_movie_data.append([title,release_year,rank])
        return top_movie_data

    def save_files_csv(self,data):
        with open("Top_movies_2.csv","w",encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(["Movie Titles","Release Year","Rank"])
            writer.writerows(data)
        print("File is saved succesfully")

# %%
api1 = api_extracter(api_key)

# %%
d1 = api1.get_data()
d1
# Out:
# [['Superman', 2025, 1],
#  ['Jurassic World: Rebirth', 2025, 2],
#  ['Dexter: Resurrection', 2025, 1],
#  ['Ballard', 2025, 2],
#  ['F1: The Movie', 2025, 3],
#  ['Sinners', 2025, 4],
#  ['Brick', 2025, 5],
#  ['The Sandman', 2022, 3],
#  ['Squid Game', 2021, 4],
#  ['The Bear', 2022, 5],
#  ['Heads of State', 2025, 6],
#  ['Too Much', 2025, 6],
#  ['The Fantastic Four: First Steps', 2025, 7],
#  ['28 Years Later', 2025, 8],
#  ['KPop Demon Hunters', 2025, 9],
#  ['The Waterfront', 2025, 7],
#  ['Ballerina', 2025, 10],
#  ['The Old Guard 2', 2025, 11],
#  ['Ironheart', 2025, 8],
#  ['Thunderbolts*', 2025, 12]]

# %%
api1.save_files_csv(d1)
# Out:
# File is saved succesfully
